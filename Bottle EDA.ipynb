# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a=pd.read_csv(r"E:\Python Data Science\Documents\9_bottle.csv")
a
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (47,73) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#         Cst_Cnt  Btl_Cnt       Sta_ID                                Depth_ID  \
# 0             1        1  054.0 056.0  19-4903CR-HY-060-0930-05400560-0000A-3
# 1             1        2  054.0 056.0  19-4903CR-HY-060-0930-05400560-0008A-3
# 2             1        3  054.0 056.0  19-4903CR-HY-060-0930-05400560-0010A-7
# 3             1        4  054.0 056.0  19-4903CR-HY-060-0930-05400560-0019A-3
# 4             1        5  054.0 056.0  19-4903CR-HY-060-0930-05400560-0020A-7
# ...         ...      ...          ...                                     ...
# 864858    34404   864859  093.4 026.4  20-1611SR-MX-310-2239-09340264-0000A-7
# 864859    34404   864860  093.4 026.4  20-1611SR-MX-310-2239-09340264-0002A-3
# ...

# %%
b=a.head(100000)
b
# Out:
#        Cst_Cnt  Btl_Cnt       Sta_ID                                Depth_ID  \
# 0            1        1  054.0 056.0  19-4903CR-HY-060-0930-05400560-0000A-3
# 1            1        2  054.0 056.0  19-4903CR-HY-060-0930-05400560-0008A-3
# 2            1        3  054.0 056.0  19-4903CR-HY-060-0930-05400560-0010A-7
# 3            1        4  054.0 056.0  19-4903CR-HY-060-0930-05400560-0019A-3
# 4            1        5  054.0 056.0  19-4903CR-HY-060-0930-05400560-0020A-7
# ...        ...      ...          ...                                     ...
# 99995     3383    99996  074.0 053.0  19-5109PT-HY-251-0042-07400530-0057A-3
# 99996     3383    99997  074.0 053.0  19-5109PT-HY-251-0042-07400530-0075A-7
# 99997     3383    99998  074.0 053.0  19-5109PT-HY-251-0042-07400530-0078A-3
# 99998     3383    99999  074.0 053.0  19-5109PT-HY-251-0042-07400530-0100A-7
# 99999     3383   100000  074.0 053.0  19-5109PT-HY-251-0042-07400530-0122A-3
#
# ...

# %%
#to find null values
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 74 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Cst_Cnt              100000 non-null  int64
#  1   Btl_Cnt              100000 non-null  int64
#  2   Sta_ID               100000 non-null  object
#  3   Depth_ID             100000 non-null  object
#  4   Depthm               100000 non-null  int64
#  5   T_degC               97895 non-null   float64
#  6   Salnty               74360 non-null   float64
#  7   O2ml_L               86693 non-null   float64
#  8   STheta               73611 non-null   float64
#  9   O2Sat                67049 non-null   float64
#  10  Oxy_µmol/Kg          67049 non-null   float64
#  11  BtlNum               0 non-null       float64
#  12  RecInd               100000 non-null  int64
#  13  T_prec               97895 non-null   float64
# ...

# %%
# to display summary of statistics
b.describe()
# Out:
#              Cst_Cnt        Btl_Cnt         Depthm        T_degC  \
# count  100000.000000  100000.000000  100000.000000  97895.000000
# mean     1651.227600   50000.500000     369.328580      9.098469
# std       968.719887   28867.657797     401.557767      4.482319
# min         1.000000       1.000000       0.000000      1.540000
# 25%       811.000000   25000.750000      73.000000      5.310000
# 50%      1616.000000   50000.500000     200.000000      8.330000
# 75%      2508.000000   75000.250000     600.000000     12.010000
# max      3383.000000  100000.000000    3762.000000     28.540000
#
#              Salnty        O2ml_L        STheta         O2Sat   Oxy_µmol/Kg  \
# count  74360.000000  86693.000000  73611.000000  67049.000000  67049.000000
# mean      33.883527      2.732315     26.116003     45.908333    122.053198
# std        0.531202      2.117817      1.096576     37.187560     92.870150
# ...

# %%
# to display column heading
b.columns
# Out:
# Index(['Cst_Cnt', 'Btl_Cnt', 'Sta_ID', 'Depth_ID', 'Depthm', 'T_degC',
#        'Salnty', 'O2ml_L', 'STheta', 'O2Sat', 'Oxy_µmol/Kg', 'BtlNum',
#        'RecInd', 'T_prec', 'T_qual', 'S_prec', 'S_qual', 'P_qual', 'O_qual',
#        'SThtaq', 'O2Satq', 'ChlorA', 'Chlqua', 'Phaeop', 'Phaqua', 'PO4uM',
#        'PO4q', 'SiO3uM', 'SiO3qu', 'NO2uM', 'NO2q', 'NO3uM', 'NO3q', 'NH3uM',
#        'NH3q', 'C14As1', 'C14A1p', 'C14A1q', 'C14As2', 'C14A2p', 'C14A2q',
#        'DarkAs', 'DarkAp', 'DarkAq', 'MeanAs', 'MeanAp', 'MeanAq', 'IncTim',
#        'LightP', 'R_Depth', 'R_TEMP', 'R_POTEMP', 'R_SALINITY', 'R_SIGMA',
#        'R_SVA', 'R_DYNHT', 'R_O2', 'R_O2Sat', 'R_SIO3', 'R_PO4', 'R_NO3',
#        'R_NO2', 'R_NH4', 'R_CHLA', 'R_PHAEO', 'R_PRES', 'R_SAMP', 'DIC1',
#        'DIC2', 'TA1', 'TA2', 'pH2', 'pH1', 'DIC Quality Comment'],
#       dtype='object')

# %%
c=b.dropna(axis=1)
c
# Out:
#        Cst_Cnt  Btl_Cnt       Sta_ID                                Depth_ID  \
# 0            1        1  054.0 056.0  19-4903CR-HY-060-0930-05400560-0000A-3
# 1            1        2  054.0 056.0  19-4903CR-HY-060-0930-05400560-0008A-3
# 2            1        3  054.0 056.0  19-4903CR-HY-060-0930-05400560-0010A-7
# 3            1        4  054.0 056.0  19-4903CR-HY-060-0930-05400560-0019A-3
# 4            1        5  054.0 056.0  19-4903CR-HY-060-0930-05400560-0020A-7
# ...        ...      ...          ...                                     ...
# 99995     3383    99996  074.0 053.0  19-5109PT-HY-251-0042-07400530-0057A-3
# 99996     3383    99997  074.0 053.0  19-5109PT-HY-251-0042-07400530-0075A-7
# 99997     3383    99998  074.0 053.0  19-5109PT-HY-251-0042-07400530-0078A-3
# 99998     3383    99999  074.0 053.0  19-5109PT-HY-251-0042-07400530-0100A-7
# 99999     3383   100000  074.0 053.0  19-5109PT-HY-251-0042-07400530-0122A-3
#
# ...

# %%
c.columns
# Out:
# Index(['Cst_Cnt', 'Btl_Cnt', 'Sta_ID', 'Depth_ID', 'Depthm', 'RecInd',
#        'P_qual', 'Chlqua', 'Phaqua', 'SiO3qu', 'NO2q', 'NO3q', 'NH3q',
#        'C14A1q', 'C14A2q', 'DarkAq', 'MeanAq', 'R_Depth', 'R_PRES'],
#       dtype='object')

# %% [markdown]
# # EDA and Visualization

# %%
sns.pairplot(c)

# %%
#normal distribution
sns.distplot(a["R_Depth"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='R_Depth', ylabel='Density'>

# %%
d=c[['Cst_Cnt', 'Btl_Cnt', 'Sta_ID', 'Depth_ID', 'Depthm', 'RecInd',
       'P_qual', 'Chlqua', 'Phaqua', 'SiO3qu', 'NO2q', 'NO3q', 'NH3q',
       'C14A1q', 'C14A2q', 'DarkAq', 'MeanAq', 'R_Depth', 'R_PRES']]

# %%
# Correlation map
sns.heatmap(d.corr())
# Out:
# <AxesSubplot:>

# %%
x=c[['Cst_Cnt', 'Btl_Cnt', 'Depthm', 'RecInd',
       'P_qual', 'Chlqua', 'Phaqua', 'SiO3qu', 'NO2q', 'NO3q', 'NH3q',
       'C14A1q', 'C14A2q', 'DarkAq', 'MeanAq']]
y=c['DarkAq']

# %%
# to split my dataset into training and test data

from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(lr.intercept_)
# Out:
# 9.0

# %%
coeff=pd.DataFrame(lr.coef_,x.columns,columns=['Co-efficient'])
coeff
# Out:
#          Co-efficient
# Cst_Cnt           0.0
# Btl_Cnt           0.0
# Depthm            0.0
# RecInd            0.0
# P_qual            0.0
# Chlqua            0.0
# Phaqua            0.0
# SiO3qu            0.0
# NO2q              0.0
# NO3q              0.0
# NH3q              0.0
# C14A1q            0.0
# C14A2q            0.0
# DarkAq            0.0
# MeanAq            0.0

# %%
#Predicting

prediction=lr.predict(x_test)
plt.scatter(y_test,prediction)

# %%
# Score

print(lr.score(x_test,y_test))
# Out:
# 1.0
